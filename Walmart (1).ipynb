# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r'D:\sitha.csv\Walmart Sales Data.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df = data.copy()

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#Create a histogram for the 'Unit price' column
plt.figure(figsize=(10, 6))
sns.histplot(data['Unit price'], bins=30, kde=True, color='blue')
plt.title('Distribution of Unit Price', fontsize=16)
plt.xlabel('Unit Price', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Boxplot for 'Total' grouped by 'Product line'
plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='Product line', y='Total', palette='Set2')
plt.title('Total Sales by Product Line', fontsize=16)
plt.xlabel('Product Line', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Branch', palette='Set2')
plt.title('Branch Frequency', fontsize=16)
plt.xlabel('Branch', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='City', palette='Set2')
plt.title('City Frequency', fontsize=16)
plt.xlabel('City', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import warnings
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Payment', palette='Set2')
plt.title('Payment Method Frequency', fontsize=16)
plt.xlabel('Payment Method', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Total', y='Rating', hue='Payment', palette='coolwarm')
plt.title('Total vs. Rating', fontsize=16)
plt.xlabel('Total', fontsize=12)
plt.ylabel('Rating', fontsize=12)
plt.grid(linestyle='--', alpha=0.7)
plt.legend(title='Payment Method', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Quantity', y='gross income', hue='Branch', style='Gender', palette='Set1')
plt.title('Quantity vs. Gross Income', fontsize=16)
plt.xlabel('Quantity', fontsize=12)
plt.ylabel('Gross Income', fontsize=12)
plt.grid(linestyle='--', alpha=0.7)
plt.legend(title='Branch', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
from scipy.stats import ttest_ind
# Filter the data by customer type
ratings_member = df[df['Customer type'] == 'Member']['Rating']
ratings_normal = df[df['Customer type'] == 'Normal']['Rating']

# Perform the two-sample t-test
t_stat, p_value = ttest_ind(ratings_member, ratings_normal, equal_var=False)  # Assuming unequal variances

# Print the results
print(f"T-Statistic: {t_stat:.4f}")
print(f"P-Value: {p_value:.4f}")

# Interpretation
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in ratings between Member and Normal customers.")
else:
    print("Fail to reject the null hypothesis: No significant difference in ratings between Member and Normal customers.")
# Out:
# T-Statistic: -0.5969
# P-Value: 0.5507
# Fail to reject the null hypothesis: No significant difference in ratings between Member and Normal customers.
